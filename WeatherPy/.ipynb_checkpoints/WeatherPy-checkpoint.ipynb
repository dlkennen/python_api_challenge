# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
lat_long_f = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        lat_long_f.append(lat_lng)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
short_cities = cities[0:10]
print(short_cities)
# Out:
# ['tuktoyaktuk', 'albany', 'beringovskiy', 'la asuncion', 'punta arenas', 'saint-philippe', 'mataura', 'mahebourg', 'butaritari', 'qaqortoq']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#Print heading
print("Beginning Data Retrieval")
print("-------------------------")

#Start index
index = 1
set = 1

#Initialize lists
temp_list = []
humidity_list = []
cloudy_list = []
wind_list = []
country_list = []
time_list = []

#Loop through city list
for city in cities:  
   
    #Get weather data and append the values to lists
    weather_response = requests.get(query_url + city)
    weather_json = weather_response.json()       
    
    try:
        temperature = weather_json["main"]["temp_max"]
        temp_list.append(temperature)
        print(f"Processing Record {index} of Set {set} | {city}") 
    except KeyError:
        temp_list.append(np.NaN)
        print(f"No data available for {index} of Set {set} | {city}") 
            
    try:
        humidity = weather_json["main"]["humidity"]
        humidity_list.append(humidity)
        if humidity>100:
            print(f"{city} has a humidity greater than 100.")
    except KeyError:
        humidity_list.append(np.NaN)
    
    try:
        wind_speed = weather_json["wind"]["speed"]
        wind_list.append(wind_speed)
    except KeyError:
        wind_list.append(np.NaN)
    
    try:
        clouds = weather_json["clouds"]["all"]
        cloudy_list.append(clouds)
    except KeyError:
        cloudy_list.append(np.NaN)
        
    try:
        country = weather_json["sys"]["country"]
        country_list.append(country)
    except KeyError:
        country_list.append(np.NaN)
    
    try:
        date_time = weather_json["dt"]
        time_list.append(date_time)
    except KeyError:
        time_list.append(np.NaN)
    
    index += 1
    time.sleep(0.9)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | beringovskiy
# Processing Record 4 of Set 1 | la asuncion
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | alugan
# Processing Record 13 of Set 1 | korla
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | sabha
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | jalu
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | tomatlan
# Processing Record 21 of Set 1 | khatanga
# No data available for 22 of Set 1 | labutta
# Processing Record 23 of Set 1 | touros
# Processing Record 24 of Set 1 | sitka
# Processing Record 25 of Set 1 | kushima
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | yelan
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | tura
# No data available for 30 of Set 1 | taolanaro
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | luderitz
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | kalianget
# Processing Record 36 of Set 1 | rassvet
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | wuchang
# Processing Record 39 of Set 1 | nanzhang
# Processing Record 40 of Set 1 | muros
# No data available for 41 of Set 1 | illoqqortoormiut
# Processing Record 42 of Set 1 | rocha
# No data available for 43 of Set 1 | grand river south east
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | meulaboh
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | sharkan
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | beian
# Processing Record 50 of Set 1 | castro
# Processing Record 51 of Set 1 | shimoda
# Processing Record 52 of Set 1 | fort nelson
# Processing Record 53 of Set 1 | nikolskoye
# Processing Record 54 of Set 1 | merrill
# Processing Record 55 of Set 1 | jamestown
# Processing Record 56 of Set 1 | new norfolk
# Processing Record 57 of Set 1 | kruisfontein
# Processing Record 58 of Set 1 | bandarbeyla
# Processing Record 59 of Set 1 | vila franca do campo
# Processing Record 60 of Set 1 | bubaque
# Processing Record 61 of Set 1 | atuona
# Processing Record 62 of Set 1 | port alfred
# Processing Record 63 of Set 1 | esperance
# Processing Record 64 of Set 1 | bethel
# Processing Record 65 of Set 1 | resistencia
# Processing Record 66 of Set 1 | bairiki
# No data available for 67 of Set 1 | mys shmidta
# Processing Record 68 of Set 1 | faanui
# Processing Record 69 of Set 1 | atambua
# Processing Record 70 of Set 1 | lagoa
# Processing Record 71 of Set 1 | svetlogorsk
# Processing Record 72 of Set 1 | nome
# Processing Record 73 of Set 1 | terrace bay
# Processing Record 74 of Set 1 | oriximina
# Processing Record 75 of Set 1 | ilheus
# Processing Record 76 of Set 1 | severo-kurilsk
# No data available for 77 of Set 1 | barentsburg
# No data available for 78 of Set 1 | bolungarvik
# No data available for 79 of Set 1 | belushya guba
# Processing Record 80 of Set 1 | chuy
# Processing Record 81 of Set 1 | ekhabi
# Processing Record 82 of Set 1 | mar del plata
# Processing Record 83 of Set 1 | provideniya
# Processing Record 84 of Set 1 | beloha
# Processing Record 85 of Set 1 | cockburn town
# Processing Record 86 of Set 1 | kapaa
# No data available for 87 of Set 1 | aflu
# No data available for 88 of Set 1 | nizhneyansk
# Processing Record 89 of Set 1 | sobolevo
# No data available for 90 of Set 1 | samalaeulu
# Processing Record 91 of Set 1 | port moresby
# Processing Record 92 of Set 1 | hermanus
# Processing Record 93 of Set 1 | santiago
# Processing Record 94 of Set 1 | dargaville
# Processing Record 95 of Set 1 | yellowknife
# Processing Record 96 of Set 1 | kalmunai
# Processing Record 97 of Set 1 | dikson
# Processing Record 98 of Set 1 | barrow
# Processing Record 99 of Set 1 | derby
# No data available for 100 of Set 1 | kuche
# Processing Record 101 of Set 1 | pangnirtung
# Processing Record 102 of Set 1 | sept-iles
# Processing Record 103 of Set 1 | igis
# Processing Record 104 of Set 1 | cruzeiro do sul
# No data available for 105 of Set 1 | tsihombe
# Processing Record 106 of Set 1 | namatanai
# Processing Record 107 of Set 1 | bluff
# Processing Record 108 of Set 1 | zelenogorskiy
# Processing Record 109 of Set 1 | kholmogory
# Processing Record 110 of Set 1 | rumford
# Processing Record 111 of Set 1 | cape town
# Processing Record 112 of Set 1 | norman wells
# Processing Record 113 of Set 1 | airai
# Processing Record 114 of Set 1 | victoria
# Processing Record 115 of Set 1 | goderich
# Processing Record 116 of Set 1 | moville
# Processing Record 117 of Set 1 | port hardy
# Processing Record 118 of Set 1 | tiksi
# Processing Record 119 of Set 1 | aguilares
# Processing Record 120 of Set 1 | ahipara
# Processing Record 121 of Set 1 | vaitape
# Processing Record 122 of Set 1 | ust-nera
# Processing Record 123 of Set 1 | lebu
# Processing Record 124 of Set 1 | ponta do sol
# Processing Record 125 of Set 1 | ancud
# Processing Record 126 of Set 1 | micheweni
# No data available for 127 of Set 1 | bolonchen
# Processing Record 128 of Set 1 | oga
# Processing Record 129 of Set 1 | new philadelphia
# Processing Record 130 of Set 1 | shambu
# Processing Record 131 of Set 1 | lompoc
# Processing Record 132 of Set 1 | golub-dobrzyn
# Processing Record 133 of Set 1 | marsh harbour
# Processing Record 134 of Set 1 | mazagao
# Processing Record 135 of Set 1 | port elizabeth
# Processing Record 136 of Set 1 | hithadhoo
# Processing Record 137 of Set 1 | arraial do cabo
# Processing Record 138 of Set 1 | teahupoo
# Processing Record 139 of Set 1 | venezuela
# Processing Record 140 of Set 1 | ushuaia
# Processing Record 141 of Set 1 | ilulissat
# Processing Record 142 of Set 1 | marawi
# Processing Record 143 of Set 1 | ostrovnoy
# Processing Record 144 of Set 1 | bangassou
# No data available for 145 of Set 1 | rungata
# No data available for 146 of Set 1 | palabuhanratu
# Processing Record 147 of Set 1 | margate
# Processing Record 148 of Set 1 | san patricio
# Processing Record 149 of Set 1 | boa vista
# Processing Record 150 of Set 1 | oranjestad
# Processing Record 151 of Set 1 | yulara
# Processing Record 152 of Set 1 | sungaipenuh
# Processing Record 153 of Set 1 | aktash
# Processing Record 154 of Set 1 | cherskiy
# Processing Record 155 of Set 1 | gisborne
# Processing Record 156 of Set 1 | sira
# No data available for 157 of Set 1 | meyungs
# Processing Record 158 of Set 1 | souillac
# Processing Record 159 of Set 1 | hualmay
# Processing Record 160 of Set 1 | longyearbyen
# Processing Record 161 of Set 1 | mayumba
# Processing Record 162 of Set 1 | senanga
# Processing Record 163 of Set 1 | komsomolskiy
# Processing Record 164 of Set 1 | torbay
# Processing Record 165 of Set 1 | irpa irpa
# Processing Record 166 of Set 1 | linxia
# Processing Record 167 of Set 1 | general roca
# Processing Record 168 of Set 1 | kindu
# Processing Record 169 of Set 1 | kostino
# Processing Record 170 of Set 1 | sao filipe
# Processing Record 171 of Set 1 | san jeronimo
# Processing Record 172 of Set 1 | mapiri
# Processing Record 173 of Set 1 | ouadda
# Processing Record 174 of Set 1 | port blair
# Processing Record 175 of Set 1 | anadyr
# No data available for 176 of Set 1 | sedelnikovo
# Processing Record 177 of Set 1 | ilo
# Processing Record 178 of Set 1 | ambilobe
# Processing Record 179 of Set 1 | hervey bay
# Processing Record 180 of Set 1 | kavieng
# Processing Record 181 of Set 1 | pisco
# Processing Record 182 of Set 1 | pasighat
# Processing Record 183 of Set 1 | fortuna
# Processing Record 184 of Set 1 | semirom
# Processing Record 185 of Set 1 | constitucion
# Processing Record 186 of Set 1 | koshurnikovo
# Processing Record 187 of Set 1 | glenwood springs
# Processing Record 188 of Set 1 | zeya
# Processing Record 189 of Set 1 | mareeba
# Processing Record 190 of Set 1 | peniche
# Processing Record 191 of Set 1 | pacifica
# Processing Record 192 of Set 1 | mao
# Processing Record 193 of Set 1 | shelburne
# Processing Record 194 of Set 1 | arvika
# Processing Record 195 of Set 1 | fare
# Processing Record 196 of Set 1 | saskylakh
# Processing Record 197 of Set 1 | solnechnyy
# Processing Record 198 of Set 1 | the pas
# Processing Record 199 of Set 1 | vaini
# Processing Record 200 of Set 1 | kloulklubed
# Processing Record 201 of Set 1 | cabo san lucas
# Processing Record 202 of Set 1 | adelaide
# Processing Record 203 of Set 1 | pangody
# Processing Record 204 of Set 1 | viedma
# Processing Record 205 of Set 1 | pacific grove
# No data available for 206 of Set 1 | halalo
# Processing Record 207 of Set 1 | nicolas bravo
# Processing Record 208 of Set 1 | ayacucho
# Processing Record 209 of Set 1 | sangueya
# Processing Record 210 of Set 1 | ugoofaaru
# Processing Record 211 of Set 1 | bomet
# Processing Record 212 of Set 1 | tonantins
# Processing Record 213 of Set 1 | rawson
# Processing Record 214 of Set 1 | nizhniy kuranakh
# No data available for 215 of Set 1 | bargal
# Processing Record 216 of Set 1 | chincha alta
# Processing Record 217 of Set 1 | tabuk
# No data available for 218 of Set 1 | mrirt
# Processing Record 219 of Set 1 | burnie
# Processing Record 220 of Set 1 | pevek
# No data available for 221 of Set 1 | saleaula
# Processing Record 222 of Set 1 | osakarovka
# Processing Record 223 of Set 1 | teguldet
# Processing Record 224 of Set 1 | saint george
# Processing Record 225 of Set 1 | godda
# Processing Record 226 of Set 1 | east london
# Processing Record 227 of Set 1 | qui nhon
# Processing Record 228 of Set 1 | walvis bay
# Processing Record 229 of Set 1 | lorengau
# Processing Record 230 of Set 1 | nabire
# Processing Record 231 of Set 1 | san cristobal
# Processing Record 232 of Set 1 | lasa
# Processing Record 233 of Set 1 | kahului
# Processing Record 234 of Set 1 | santiago de cao
# Processing Record 235 of Set 1 | kupang
# Processing Record 236 of Set 1 | bandipur
# Processing Record 237 of Set 1 | vicuna
# No data available for 238 of Set 1 | attawapiskat
# Processing Record 239 of Set 1 | grand gaube
# Processing Record 240 of Set 1 | danville
# No data available for 241 of Set 1 | vaitupu
# Processing Record 242 of Set 1 | vao
# Processing Record 243 of Set 1 | huarmey
# Processing Record 244 of Set 1 | nyurba
# Processing Record 245 of Set 1 | ponta delgada
# Processing Record 246 of Set 1 | honiara
# Processing Record 247 of Set 1 | mersin
# Processing Record 248 of Set 1 | chokurdakh
# Processing Record 249 of Set 1 | skjervoy
# Processing Record 250 of Set 1 | avera
# Processing Record 251 of Set 1 | ulladulla
# Processing Record 252 of Set 1 | lavrentiya
# Processing Record 253 of Set 1 | bom jardim
# Processing Record 254 of Set 1 | coxim
# Processing Record 255 of Set 1 | alice springs
# Processing Record 256 of Set 1 | xining
# Processing Record 257 of Set 1 | alghero
# Processing Record 258 of Set 1 | asfi
# Processing Record 259 of Set 1 | sorumsand
# Processing Record 260 of Set 1 | dwarka
# Processing Record 261 of Set 1 | tasiilaq
# Processing Record 262 of Set 1 | maumere
# Processing Record 263 of Set 1 | camacha
# Processing Record 264 of Set 1 | cayenne
# Processing Record 265 of Set 1 | valparaiso
# Processing Record 266 of Set 1 | thompson
# Processing Record 267 of Set 1 | oranjemund
# Processing Record 268 of Set 1 | kamir
# Processing Record 269 of Set 1 | poum
# Processing Record 270 of Set 1 | svetlyy
# Processing Record 271 of Set 1 | leningradskiy
# Processing Record 272 of Set 1 | kenora
# Processing Record 273 of Set 1 | hasaki
# Processing Record 274 of Set 1 | qaanaaq
# Processing Record 275 of Set 1 | newport
# Processing Record 276 of Set 1 | saint-pierre
# Processing Record 277 of Set 1 | tual
# Processing Record 278 of Set 1 | hazorasp
# Processing Record 279 of Set 1 | okha
# Processing Record 280 of Set 1 | tongchuan
# Processing Record 281 of Set 1 | san roque
# Processing Record 282 of Set 1 | amapa
# Processing Record 283 of Set 1 | saint-leu
# Processing Record 284 of Set 1 | atar
# Processing Record 285 of Set 1 | carnarvon
# Processing Record 286 of Set 1 | cap malheureux
# Processing Record 287 of Set 1 | fairbanks
# Processing Record 288 of Set 1 | talnakh
# Processing Record 289 of Set 1 | iqaluit
# Processing Record 290 of Set 1 | superior
# Processing Record 291 of Set 1 | ca mau
# Processing Record 292 of Set 1 | altagracia de orituco
# Processing Record 293 of Set 1 | shubarshi
# Processing Record 294 of Set 1 | garowe
# Processing Record 295 of Set 1 | shahr-e kord
# Processing Record 296 of Set 1 | aquiraz
# Processing Record 297 of Set 1 | hof
# Processing Record 298 of Set 1 | padang
# Processing Record 299 of Set 1 | kulhudhuffushi
# Processing Record 300 of Set 1 | santiago del estero
# No data available for 301 of Set 1 | kracheh
# Processing Record 302 of Set 1 | zonguldak
# Processing Record 303 of Set 1 | saint-francois
# Processing Record 304 of Set 1 | udala
# Processing Record 305 of Set 1 | pahrump
# Processing Record 306 of Set 1 | nahavand
# Processing Record 307 of Set 1 | upernavik
# Processing Record 308 of Set 1 | narsaq
# Processing Record 309 of Set 1 | baykit
# Processing Record 310 of Set 1 | yilan
# Processing Record 311 of Set 1 | praia da vitoria
# Processing Record 312 of Set 1 | kabare
# Processing Record 313 of Set 1 | quatre cocos
# Processing Record 314 of Set 1 | mae sai
# Processing Record 315 of Set 1 | ciro marina
# No data available for 316 of Set 1 | tasbuget
# Processing Record 317 of Set 1 | eyl
# Processing Record 318 of Set 1 | davila
# Processing Record 319 of Set 1 | nara
# Processing Record 320 of Set 1 | cidreira
# Processing Record 321 of Set 1 | piacabucu
# No data available for 322 of Set 1 | barroualie
# Processing Record 323 of Set 1 | finschhafen
# Processing Record 324 of Set 1 | roma
# Processing Record 325 of Set 1 | zhezkazgan
# Processing Record 326 of Set 1 | asosa
# Processing Record 327 of Set 1 | lujan
# Processing Record 328 of Set 1 | monze
# No data available for 329 of Set 1 | yanan
# Processing Record 330 of Set 1 | mayo
# Processing Record 331 of Set 1 | obo
# Processing Record 332 of Set 1 | caravelas
# Processing Record 333 of Set 1 | roald
# No data available for 334 of Set 1 | amderma
# Processing Record 335 of Set 1 | paamiut
# Processing Record 336 of Set 1 | waingapu
# Processing Record 337 of Set 1 | saint-augustin
# Processing Record 338 of Set 1 | aklavik
# Processing Record 339 of Set 1 | san quintin
# No data available for 340 of Set 1 | jinchengjiang
# Processing Record 341 of Set 1 | tateyama
# Processing Record 342 of Set 1 | hofn
# Processing Record 343 of Set 1 | pemba
# Processing Record 344 of Set 1 | tomohon
# No data available for 345 of Set 1 | gangotri
# Processing Record 346 of Set 1 | teya
# Processing Record 347 of Set 1 | wairoa
# Processing Record 348 of Set 1 | pasni
# Processing Record 349 of Set 1 | miri
# Processing Record 350 of Set 1 | tuy hoa
# Processing Record 351 of Set 1 | plettenberg bay
# Processing Record 352 of Set 1 | mananjary
# Processing Record 353 of Set 1 | sarh
# Processing Record 354 of Set 1 | mahibadhoo
# Processing Record 355 of Set 1 | hami
# Processing Record 356 of Set 1 | sibu
# Processing Record 357 of Set 1 | vanimo
# Processing Record 358 of Set 1 | senno
# Processing Record 359 of Set 1 | libertador general san martin
# Processing Record 360 of Set 1 | samarai
# Processing Record 361 of Set 1 | chik
# Processing Record 362 of Set 1 | lovozero
# Processing Record 363 of Set 1 | vila
# Processing Record 364 of Set 1 | clyde river
# Processing Record 365 of Set 1 | baturaja
# Processing Record 366 of Set 1 | baglung
# Processing Record 367 of Set 1 | loandjili
# Processing Record 368 of Set 1 | nakhon phanom
# Processing Record 369 of Set 1 | vinh
# Processing Record 370 of Set 1 | salalah
# Processing Record 371 of Set 1 | pueblo nuevo
# Processing Record 372 of Set 1 | naze
# Processing Record 373 of Set 1 | cabinda
# Processing Record 374 of Set 1 | paracatu
# Processing Record 375 of Set 1 | syracuse
# Processing Record 376 of Set 1 | clearlake
# Processing Record 377 of Set 1 | comodoro rivadavia
# Processing Record 378 of Set 1 | phonhong
# Processing Record 379 of Set 1 | elko
# Processing Record 380 of Set 1 | trairi
# Processing Record 381 of Set 1 | dingle
# Processing Record 382 of Set 1 | shache
# Processing Record 383 of Set 1 | lazaro cardenas
# No data available for 384 of Set 1 | dolbeau
# Processing Record 385 of Set 1 | montbrison
# Processing Record 386 of Set 1 | quelimane
# Processing Record 387 of Set 1 | gbarnga
# Processing Record 388 of Set 1 | port lincoln
# Processing Record 389 of Set 1 | duku
# Processing Record 390 of Set 1 | bose
# Processing Record 391 of Set 1 | mangai
# Processing Record 392 of Set 1 | margherita
# Processing Record 393 of Set 1 | mehamn
# Processing Record 394 of Set 1 | gull lake
# Processing Record 395 of Set 1 | radece
# Processing Record 396 of Set 1 | olafsvik
# Processing Record 397 of Set 1 | sakaiminato
# Processing Record 398 of Set 1 | suntar
# Processing Record 399 of Set 1 | husavik
# Processing Record 400 of Set 1 | san ramon
# Processing Record 401 of Set 1 | robertsport
# Processing Record 402 of Set 1 | medeiros neto
# Processing Record 403 of Set 1 | vila velha
# No data available for 404 of Set 1 | toliary
# Processing Record 405 of Set 1 | zhanaozen
# Processing Record 406 of Set 1 | rio grande
# No data available for 407 of Set 1 | kamenskoye
# Processing Record 408 of Set 1 | koslan
# Processing Record 409 of Set 1 | lockport
# No data available for 410 of Set 1 | cumaribo
# Processing Record 411 of Set 1 | sambava
# Processing Record 412 of Set 1 | nunoa
# Processing Record 413 of Set 1 | kavaratti
# Processing Record 414 of Set 1 | yinchuan
# Processing Record 415 of Set 1 | balakhninskiy
# Processing Record 416 of Set 1 | kushiro
# Processing Record 417 of Set 1 | gat
# Processing Record 418 of Set 1 | sao joao da barra
# Processing Record 419 of Set 1 | vardo
# Processing Record 420 of Set 1 | indian head
# Processing Record 421 of Set 1 | kaitangata
# No data available for 422 of Set 1 | safwah
# Processing Record 423 of Set 1 | banfora
# Processing Record 424 of Set 1 | nhulunbuy
# No data available for 425 of Set 1 | lolua
# Processing Record 426 of Set 1 | inuvik
# Processing Record 427 of Set 1 | nauta
# Processing Record 428 of Set 1 | maceio
# Processing Record 429 of Set 1 | ankang
# Processing Record 430 of Set 1 | nobres
# Processing Record 431 of Set 1 | yeppoon
# Processing Record 432 of Set 1 | jagtial
# Processing Record 433 of Set 1 | odweyne
# Processing Record 434 of Set 1 | jaumave
# Processing Record 435 of Set 1 | qandala
# Processing Record 436 of Set 1 | arecibo
# Processing Record 437 of Set 1 | altay
# Processing Record 438 of Set 1 | arona
# Processing Record 439 of Set 1 | aripuana
# Processing Record 440 of Set 1 | kodinar
# Processing Record 441 of Set 1 | mackenzie
# Processing Record 442 of Set 1 | kudahuvadhoo
# No data available for 443 of Set 1 | dzhusaly
# No data available for 444 of Set 1 | ambodifototra
# Processing Record 445 of Set 1 | bayanday
# Processing Record 446 of Set 1 | sur
# Processing Record 447 of Set 1 | bonavista
# Processing Record 448 of Set 1 | chengde
# Processing Record 449 of Set 1 | sasovo
# Processing Record 450 of Set 1 | nouadhibou
# Processing Record 451 of Set 1 | nemuro
# Processing Record 452 of Set 1 | letlhakeng
# Processing Record 453 of Set 1 | malanje
# Processing Record 454 of Set 1 | lastoursville
# Processing Record 455 of Set 1 | cuiaba
# Processing Record 456 of Set 1 | champerico
# Processing Record 457 of Set 1 | verkhnevilyuysk
# Processing Record 458 of Set 1 | pandan
# Processing Record 459 of Set 1 | disna
# Processing Record 460 of Set 1 | khandyga
# Processing Record 461 of Set 1 | tuatapere
# Processing Record 462 of Set 1 | opuwo
# Processing Record 463 of Set 1 | sayyan
# Processing Record 464 of Set 1 | cabedelo
# Processing Record 465 of Set 1 | eyemouth
# Processing Record 466 of Set 1 | tyup
# Processing Record 467 of Set 1 | umm lajj
# Processing Record 468 of Set 1 | grants pass
# Processing Record 469 of Set 1 | sal rei
# Processing Record 470 of Set 1 | plaster rock
# Processing Record 471 of Set 1 | olinda
# Processing Record 472 of Set 1 | olga
# Processing Record 473 of Set 1 | coihaique
# Processing Record 474 of Set 1 | west bay
# No data available for 475 of Set 1 | tongsa
# Processing Record 476 of Set 1 | murbad
# Processing Record 477 of Set 1 | sirsi
# Processing Record 478 of Set 1 | kununurra
# Processing Record 479 of Set 1 | itapecerica
# Processing Record 480 of Set 1 | colares
# Processing Record 481 of Set 1 | san felipe
# Processing Record 482 of Set 1 | ozernovskiy
# Processing Record 483 of Set 1 | filingue
# No data available for 484 of Set 1 | fort saint john
# Processing Record 485 of Set 1 | arlit
# Processing Record 486 of Set 1 | tigil
# Processing Record 487 of Set 1 | mae sot
# Processing Record 488 of Set 1 | smidovich
# Processing Record 489 of Set 1 | praia
# Processing Record 490 of Set 1 | zhigansk
# Processing Record 491 of Set 1 | maridi
# No data available for 492 of Set 1 | louisbourg
# Processing Record 493 of Set 1 | acari
# Processing Record 494 of Set 1 | belyy yar
# Processing Record 495 of Set 1 | prince rupert
# Processing Record 496 of Set 1 | yambio
# Processing Record 497 of Set 1 | saint-joseph
# Processing Record 498 of Set 1 | laguna
# Processing Record 499 of Set 1 | dunedin
# Processing Record 500 of Set 1 | aksu
# Processing Record 501 of Set 1 | bathsheba
# Processing Record 502 of Set 1 | santa cruz
# No data available for 503 of Set 1 | beruni
# Processing Record 504 of Set 1 | kuytun
# Processing Record 505 of Set 1 | balabac
# Processing Record 506 of Set 1 | geraldton
# Processing Record 507 of Set 1 | imbituba
# Processing Record 508 of Set 1 | brest
# Processing Record 509 of Set 1 | faya
# Processing Record 510 of Set 1 | marigot
# Processing Record 511 of Set 1 | half moon bay
# Processing Record 512 of Set 1 | gondanglegi
# Processing Record 513 of Set 1 | gizo
# Processing Record 514 of Set 1 | nago
# Processing Record 515 of Set 1 | los llanos de aridane
# No data available for 516 of Set 1 | tuggurt
# Processing Record 517 of Set 1 | whitehorse
# Processing Record 518 of Set 1 | namibe
# Processing Record 519 of Set 1 | altamira
# Processing Record 520 of Set 1 | salym
# Processing Record 521 of Set 1 | saint anthony
# Processing Record 522 of Set 1 | coquimbo
# No data available for 523 of Set 1 | urdzhar
# Processing Record 524 of Set 1 | erenhot
# Processing Record 525 of Set 1 | nelson bay
# Processing Record 526 of Set 1 | klyuchi
# Processing Record 527 of Set 1 | steenwijk
# Processing Record 528 of Set 1 | bokoro
# Processing Record 529 of Set 1 | bystryy istok
# Processing Record 530 of Set 1 | lubango
# No data available for 531 of Set 1 | sumen
# Processing Record 532 of Set 1 | northam
# Processing Record 533 of Set 1 | boffa
# Processing Record 534 of Set 1 | bintulu
# Processing Record 535 of Set 1 | wakkanai
# Processing Record 536 of Set 1 | san vicente
# Processing Record 537 of Set 1 | taltal
# Processing Record 538 of Set 1 | vallenar
# Processing Record 539 of Set 1 | stromness
# Processing Record 540 of Set 1 | yar-sale
# Processing Record 541 of Set 1 | aurillac
# Processing Record 542 of Set 1 | bowen
# Processing Record 543 of Set 1 | kurilsk
# Processing Record 544 of Set 1 | abha
# Processing Record 545 of Set 1 | bairnsdale
# Processing Record 546 of Set 1 | malpe
# Processing Record 547 of Set 1 | lebork
# Processing Record 548 of Set 1 | achutupo
# No data available for 549 of Set 1 | samusu
# Processing Record 550 of Set 1 | donskoye
# Processing Record 551 of Set 1 | puerto cabezas
# Processing Record 552 of Set 1 | sepolno krajenskie
# Processing Record 553 of Set 1 | mitu
# Processing Record 554 of Set 1 | mount gambier
# Processing Record 555 of Set 1 | wanning
# Processing Record 556 of Set 1 | mildura
# Processing Record 557 of Set 1 | krasnyy chikoy
# Processing Record 558 of Set 1 | kuruman
# Processing Record 559 of Set 1 | sinegorye
# Processing Record 560 of Set 1 | arcachon
# Processing Record 561 of Set 1 | necochea
# Processing Record 562 of Set 1 | batagay
# Processing Record 563 of Set 1 | coahuayana
# Processing Record 564 of Set 1 | vydrino
# Processing Record 565 of Set 1 | roznava
# Processing Record 566 of Set 1 | monterey
# No data available for 567 of Set 1 | taburi
# Processing Record 568 of Set 1 | buraydah
# Processing Record 569 of Set 1 | townsville
# Processing Record 570 of Set 1 | biak
# Processing Record 571 of Set 1 | sakakah
# Processing Record 572 of Set 1 | portland
# Processing Record 573 of Set 1 | nisia floresta
# Processing Record 574 of Set 1 | srandakan
# Processing Record 575 of Set 1 | rio gallegos
# Processing Record 576 of Set 1 | oyek
# Processing Record 577 of Set 1 | tianpeng
# Processing Record 578 of Set 1 | khanpur
# Processing Record 579 of Set 1 | norsup
# Processing Record 580 of Set 1 | barranca
# Processing Record 581 of Set 1 | basco
# Processing Record 582 of Set 1 | katsuura
# Processing Record 583 of Set 1 | tahara
# No data available for 584 of Set 1 | huazolotitlan
# Processing Record 585 of Set 1 | polohy
# Processing Record 586 of Set 1 | lashio
# Processing Record 587 of Set 1 | college
# Processing Record 588 of Set 1 | sistranda
# Processing Record 589 of Set 1 | jiuquan
# Processing Record 590 of Set 1 | ishigaki
# Processing Record 591 of Set 1 | basar
# Processing Record 592 of Set 1 | santa cruz de la palma
# Processing Record 593 of Set 1 | hue
# Processing Record 594 of Set 1 | soledade
# Processing Record 595 of Set 1 | stirling
# Processing Record 596 of Set 1 | batemans bay
# Processing Record 597 of Set 1 | williams lake
# Processing Record 598 of Set 1 | saurimo
# No data available for 599 of Set 1 | gurskoye
# Processing Record 600 of Set 1 | havre-saint-pierre
# Processing Record 601 of Set 1 | te anau
# No data available for 602 of Set 1 | umzimvubu
# Processing Record 603 of Set 1 | agadir
# Processing Record 604 of Set 1 | whyalla
# Processing Record 605 of Set 1 | dibulla
# Processing Record 606 of Set 1 | jasper
# Processing Record 607 of Set 1 | skwierzyna
# Processing Record 608 of Set 1 | shirgaon
# Processing Record 609 of Set 1 | chimbote
# Processing Record 610 of Set 1 | bengkulu
# Processing Record 611 of Set 1 | bereda
# Processing Record 612 of Set 1 | isangel
# Processing Record 613 of Set 1 | chebsara
# Processing Record 614 of Set 1 | carballo
# Processing Record 615 of Set 1 | adrar
# Processing Record 616 of Set 1 | sandwick
# Processing Record 617 of Set 1 | salinopolis
# Processing Record 618 of Set 1 | helena
# Processing Record 619 of Set 1 | oildale
# Processing Record 620 of Set 1 | djambala
# Processing Record 621 of Set 1 | bumba
# Processing Record 622 of Set 1 | launceston
# Processing Record 623 of Set 1 | nueva gerona
# Processing Record 624 of Set 1 | warin chamrap
# Processing Record 625 of Set 1 | kieta
# Processing Record 626 of Set 1 | tigzirt
# Processing Record 627 of Set 1 | mango

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
lats = [i[0] for i in lat_long_f]
longs = [i[1] for i in lat_long_f]

weather_df = pd.DataFrame(
    {"City": cities,
     "Latitude": lats,
     "Longitude": longs,
     "Temperature (°F)":temp_list,
     "Humidity": humidity_list,
     "Cloudiness": cloudy_list,
     "Wind Speed (mph)": wind_list,
     "Country": country_list,
     "Date Time": time_list})

weather_df.to_csv(output_data_file)

# %%
weather_df.head()
# Out:
#            City   Latitude   Longitude  Temperature (°F)  Humidity  \
# 0   tuktoyaktuk  70.359980 -129.812208             12.20      79.0
# 1        albany -73.542428  101.000029             37.00      55.0
# 2  beringovskiy  54.447493  175.503084             27.90      74.0
# 3   la asuncion  12.671419  -64.225423             76.95      83.0
# 4  punta arenas -76.702237 -111.875297             41.00      60.0
#
#    Cloudiness  Wind Speed (mph) Country     Date Time
# 0        40.0             26.46      CA  1.619050e+09
# 1        79.0             13.18      US  1.619050e+09
# 2        67.0              4.32      RU  1.619051e+09
# 3         1.0             14.94      VE  1.619051e+09
# 4         0.0              6.91      CL  1.619050e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Cleaning dataframe of cities with missing data
cleaned_weather_df = weather_df.dropna(axis = 0, how = "any")
cleaned_weather_df.head()
# Out:
#            City   Latitude   Longitude  Temperature (°F)  Humidity  \
# 0   tuktoyaktuk  70.359980 -129.812208             12.20      79.0
# 1        albany -73.542428  101.000029             37.00      55.0
# 2  beringovskiy  54.447493  175.503084             27.90      74.0
# 3   la asuncion  12.671419  -64.225423             76.95      83.0
# 4  punta arenas -76.702237 -111.875297             41.00      60.0
#
#    Cloudiness  Wind Speed (mph) Country     Date Time
# 0        40.0             26.46      CA  1.619050e+09
# 1        79.0             13.18      US  1.619050e+09
# 2        67.0              4.32      RU  1.619051e+09
# 3         1.0             14.94      VE  1.619051e+09
# 4         0.0              6.91      CL  1.619050e+09

# %%
#Checking for the number of valid weather data cities
print(len(cleaned_weather_df))
# Out:
# 576

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Filter the Data frame for the latitude and temperature columns
lat_and_temp = cleaned_weather_df[["Latitude", "Temperature (°F)"]]

#Use df.plot to create a scatter plot
lat_and_temp.plot(kind = "scatter", x="Latitude", y="Temperature (°F)", grid=True, title="Temperature vs Latitude (4/21/21)")

plt.savefig("output_data/fig1.png")

plt.show()

# %% [markdown]
# The above figure is depicting the relationship between latitude and temperature. The cities nearer the equator at 0° latitude have the highest temperatures. Cities in the northern hemisphere and positioned over 50°N have much lower maximum temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Filter the Data frame for the latitude and humidity columns
lat_and_hum = cleaned_weather_df[["Latitude", "Humidity"]]

#Use df.plot to create a scatter plot
lat_and_hum.plot(kind = "scatter", x="Latitude", y="Humidity", grid=True, title="Humidity vs Latitude (4/21/21)")

plt.savefig("output_data/fig2.png")

plt.show()

# %% [markdown]
# The above figure does not seem to indicate much of a correlation between humidity and latitude. Humid and dry air are found at almost all latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Filter the Data frame for the latitude and cloudiness columns
lat_and_cloud = cleaned_weather_df[["Latitude", "Cloudiness"]]

#Use df.plot to create a scatter plot
lat_and_cloud.plot(kind = "scatter", x="Latitude", y="Cloudiness", grid=True, title="Cloudiness vs Latitude (4/21/21)")

plt.savefig("output_data/fig3.png")

plt.show()

# %% [markdown]
# The above figure depicts cloud coverage as a function of latitude. This does not seem to indicate much of a correlation between cloud cover and latitude. Cloudiness levels from 0 to 100 are found at almost all latitudes.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Filter the Data frame for the latitude and cloudiness columns
lat_and_wind = cleaned_weather_df[["Latitude", "Wind Speed (mph)"]]

#Use df.plot to create a scatter plot
lat_and_wind.plot(kind = "scatter", x="Latitude", y="Wind Speed (mph)", grid=True, title="Wind Speed vs Latitude (4/21/21)")

plt.savefig("output_data/fig4.png")

plt.show()

# %% [markdown]
# This graph depicts wind speed in relation to latitude. Higher wind speeds are more prevalent in the northern hemisphere. This is probably due to the larger quantity of land mass in the northern hemisphere as compared to the southern hemisphere.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_and_temp_north = lat_and_temp[lat_and_temp["Latitude"]>=0]
x_values = lat_and_temp_north["Latitude"]
y_values = lat_and_temp_north["Temperature (°F)"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_temp_north.plot(kind = "scatter", x="Latitude", y="Temperature (°F)", grid=True, title="Temperature vs Latitude (N) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(3,10),fontsize=15,color="red")
plt.savefig("output_data/fig5.png")

plt.show()
# Out:
# R = -0.8276899351821336

# %% [markdown]
# The line of best fit shows a strong negative correlation between latitude and maximum temperature in the northern hemisphere (R = -0.83). As the locations are further north, the maximum temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_and_temp_south = lat_and_temp[lat_and_temp["Latitude"]<=0]
x_values = lat_and_temp_south["Latitude"]
y_values = lat_and_temp_south["Temperature (°F)"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_temp_south.plot(kind = "scatter", x="Latitude", y="Temperature (°F)", grid=True, title="Temperature vs Latitude (S) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-80,70),fontsize=15,color="red")
plt.savefig("output_data/fig6.png")

plt.show()
# Out:
# R = 0.47832346134580955

# %% [markdown]
# There is a moderate positive correlation (R = 0.48) in the southern hemisphere. As the locations are further south, max  temperatures are generally lower.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_and_hum_north = lat_and_hum[lat_and_hum["Latitude"]>=0]
x_values = lat_and_hum_north["Latitude"]
y_values = lat_and_hum_north["Humidity"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_hum_north.plot(kind = "scatter", x="Latitude", y="Humidity", grid=True, title="Humidity vs Latitude (N) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,60),fontsize=15,color="red")
plt.savefig("output_data/fig7.png")

plt.show()
# Out:
# R = 0.026269373841870662

# %% [markdown]
# This regression shows that no correlation (R = 0.03) exists between humidity and latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_and_hum_south = lat_and_hum[lat_and_hum["Latitude"]<=0]
x_values = lat_and_hum_south["Latitude"]
y_values = lat_and_hum_south["Humidity"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_hum_south.plot(kind = "scatter", x="Latitude", y="Humidity", grid=True, title="Humidity vs Latitude (S) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-80,40),fontsize=15,color="red")
plt.savefig("output_data/fig8.png")

plt.show()
# Out:
# R = 0.18282960345244412

# %% [markdown]
# The above scatter plot and regression also indicate little to no correlation between humidity and latitude (R = 0.18).

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_and_cloud_north = lat_and_cloud[lat_and_cloud["Latitude"]>=0]
x_values = lat_and_cloud_north["Latitude"]
y_values = lat_and_cloud_north["Cloudiness"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_cloud_north.plot(kind = "scatter", x="Latitude", y="Cloudiness", grid=True, title="Cloudiness vs Latitude (N) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,40),fontsize=15,color="red")
plt.savefig("output_data/fig9.png")

plt.show()
# Out:
# R = 0.09212142347886254

# %% [markdown]
# The scatter plot and regression above shows little to no correlation between cloudiness and latitude in the northern hemisphere (R = 0.09).

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_and_cloud_south = lat_and_cloud[lat_and_cloud["Latitude"]<=0]
x_values = lat_and_cloud_south["Latitude"]
y_values = lat_and_cloud_south["Cloudiness"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_cloud_south.plot(kind = "scatter", x="Latitude", y="Cloudiness", grid=True, title="Cloudiness vs Latitude (S) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,40),fontsize=15,color="red")
plt.savefig("output_data/fig10.png")

plt.show()
# Out:
# R = -0.046530229272712366

# %% [markdown]
# The above graph of cloudiness vs latitude shows little to no correlation (R = -0.05) between cloudiness and latitude in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_and_wind_north = lat_and_wind[lat_and_wind["Latitude"]>=0]
x_values = lat_and_wind_north["Latitude"]
y_values = lat_and_wind_north["Wind Speed (mph)"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_wind_north.plot(kind = "scatter", x="Latitude", y="Wind Speed (mph)", grid=True, title="Wind Speed vs Latitude (N) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,15),fontsize=15,color="red")
plt.savefig("output_data/fig11.png")

plt.show()
# Out:
# R = 0.1702487925260721

# %% [markdown]
# The above scatter plot show a low correlation (R = 0.17) between wind speed and latitude in the northern hemisphere. Wind speed only increases very slightly as you move north.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_and_wind_south = lat_and_wind[lat_and_wind["Latitude"]<=0]
x_values = lat_and_wind_south["Latitude"]
y_values = lat_and_wind_south["Wind Speed (mph)"]

(slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
print(f"R = {rvalue}")

#Use df.plot to create a scatter plot
lat_and_wind_south.plot(kind = "scatter", x="Latitude", y="Wind Speed (mph)", grid=True, title="Wind Speed vs Latitude (S) (4/21/21)")

#Add the line of best fit
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-80,12.5),fontsize=15,color="red")
plt.savefig("output_data/fig12.png")

plt.show()
# Out:
# R = -0.27066361169116576

# %% [markdown]
# In the southern hemisphere, there is a low to moderate negative correlation between wind speed and humidity (R = -0.27). As you move south, wind speed increases slightly.
